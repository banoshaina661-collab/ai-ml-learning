# %%
import numpy as np
print(np.random.rand(5))
# Out:
# [0.18909271 0.99415272 0.79143153 0.49857179 0.1092523 ]

# %%
print(np.random.randn(10))
# Out:
# [-0.33980141 -0.906257   -0.46119045  0.6287259   0.80803282  0.91587557
#   0.8497925  -0.17646824  0.01376461  0.31921102]

# %%
print(np.random.randint(2,5,5))
# Out:
# [2 4 3 3 3]

# %%
a=np.array([1,2,3,4])
b =np.array([5,6,7,8])
print(np.dot(a,b))
# Out:
# 70

# %%
a = np.array([[2,3],[5,7]])
b =np.array([[7,3],[4,9]])
print(np.dot(a,b))
# Out:
# [[26 33]
#  [63 78]]

# %%
c = np.array([[2,3],[5,7]])
print(c.T)
# Out:
# [[2 5]
#  [3 7]]

# %%
b =np.array([5,6,7,8])
print(np.argmax(b))
print(np.argmin(b))
# Out:
# 3
# 0

# %%
a = np.array([[2,3],[5,7]])
b =np.array([[7,3],[4,9]])
print(np.vstack((a,b)))
# Out:
# [[2 3]
#  [5 7]
#  [7 3]
#  [4 9]]

# %% [markdown]
# ##### a=np.array([1,2,3,4])
# b =np.array([5,6,7,8])
# print(np.hstack((a,b)))
# print(np.vstack((a,b)))

# %%
a =np.array([2,3,4,6])
print(np.split(a,2))
# Out:
# [array([2, 3]), array([4, 6])]

# %%
a =np.array([2,3,4,6])
print(np.split(a,2))
# Out:
# [array([2, 3]), array([4, 6])]

# %%
a=np.array([1,2,3],dtype=float)
print(a.dtype)
print(a)
# Out:
# float64
# [1. 2. 3.]

# %%
a =float(input("enter 1:"))
b =float(input("enter 1:"))
c =float(input("enter 1:"))
d=np.array([a,b,c],dtype=int)
print(d.dtype)
print(d)
# Out:
# enter 1: 2.4
# enter 1: 5.34
# enter 1:  6.78
# int64
# [2 5 6]

# %%
a =np.array([1,2,3,4,5,3,4,5,6])
print(a.nbytes)
# Out:
# 72
